# %%
from datasets import load_dataset

corpus = load_dataset("BeIR/fiqa", "corpus")

corpus
# Out:
# ...
# Generating corpus split: 100%|██████████| 57638/57638 [00:00<00:00, 206622.39 examples/s]
# DatasetDict({
#     corpus: Dataset({
#         features: ['_id', 'title', 'text'],
#         num_rows: 57638
#     })
# })

# %%
queries = load_dataset("BeIR/fiqa", "queries")
queries
# Out:
# ...
# Generating queries split: 100%|██████████| 6648/6648 [00:00<00:00, 415635.41 examples/s]
# DatasetDict({
#     queries: Dataset({
#         features: ['_id', 'title', 'text'],
#         num_rows: 6648
#     })
# })

# %%
qrels = load_dataset("BeIR/fiqa", "qrels")
qrels
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 qrels = load_dataset("BeIR/fiqa", "qrels")
#       2 qrels
#
# File d:\Enterprise RAG Assistant with Reranking and Evaluation\eraenv\Lib\site-packages\datasets\load.py:2587, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2582 verification_mode = VerificationMode(
#    2583     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2584 )
#    2586 # Create a dataset builder
# -> 2587 builder_instance = load_dataset_builder(
#    2588     path=path,
#    2589     name=name,
# ...

# %%
from beir import util
from beir.datasets.data_loader import GenericDataLoader

# Download dataset
dataset_path = util.download_and_unzip(
    "https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/fiqa.zip",
    "datasets"
)

# Load all components
corpus, queries, qrels = GenericDataLoader(dataset_path).load(split="test")
# Out:
# datasets\fiqa.zip: 100%|██████████| 17.1M/17.1M [00:25<00:00, 693kiB/s]
# 100%|██████████| 57638/57638 [00:00<00:00, 82155.15it/s]

# %%
print(type(corpus))   # dict
print(type(queries))  # dict
print(type(qrels))    # dict
# Out:
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>

# %%
qid = list(queries.keys())[0]

# %%
query = queries[qid]
relevant_docs = qrels[qid]

print("Query:", query)
print("Relevant Docs:", relevant_docs)
# Out:
# Query: How to deposit a cheque issued to an associate in my business into my business account?
# Relevant Docs: {'566392': 1, '65404': 1}

# %%
# get first query id
qid = list(queries.keys())[0]

# fetch query
query = queries[qid]

# fetch relevant docs
relevant_docs = qrels[qid]

print("Query:", query)

# print relevant documents
for doc_id in relevant_docs:
    print("Doc ID:", doc_id)
    print(corpus[doc_id])
# Out:
# Query: How to deposit a cheque issued to an associate in my business into my business account?
# Doc ID: 566392
# {'text': 'Have the check reissued to the proper payee.', 'title': ''}
# Doc ID: 65404
# {'text': "Just have the associate sign the back and then deposit it.  It's called a third party cheque and is perfectly legal.  I wouldn't be surprised if it has a longer hold period and, as always, you don't get the money if the cheque doesn't clear. Now, you may have problems if it's a large amount or you're not very well known at the bank.  In that case you can have the associate go to the bank and endorse it in front of the teller with some ID.  You don't even technically have to be there.  Anybody can deposit money to your account if they have the account number. He could also just deposit it in his account and write a cheque to the business.", 'title': ''}
